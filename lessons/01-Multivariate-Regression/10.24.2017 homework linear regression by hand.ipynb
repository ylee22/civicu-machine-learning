# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
df = pd.read_csv('../shared-resources/heights_weights_genders.csv')
df.plot.scatter(x='Height', y='Weight')

# %%
X = df[['Height', 'Weight']].values
y = (df.Gender == 'Female').astype(int)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
print(X)
# Out:
# [[ 0.79172838  0.863139  ]
#  [ 0.58695829  0.4754764 ]
#  [ 0.8023644   0.72113127]
#  ...,
#  [ 0.38830089  0.31065968]
#  [ 0.59715974  0.48298768]
#  [ 0.31052854  0.23843869]]

# %%
bias = np.random.randn(1)
weights = np.random.randn(2)
learning_rate = .1
for epoch in range(10):
    ypred = np.dot(weights.T[0], X.T) + bias
    e = (ypred - y)
    epsilon = weights.T[0] * 1e-6
    ypred2 = np.dot((weights + epsilon))
# Out:
# [ 0.55289135 -0.78014641]
